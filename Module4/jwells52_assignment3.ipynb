# %%
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Load Amazon Music Instrumental Reviews data

# %%
df = pd.read_csv('Musical_instruments_reviews.csv')
df
# Out:
#            reviewerID        asin  \
# 0      A2IBPI20UZIR0U  1384719342
# 1      A14VAT5EAX3D9S  1384719342
# 2      A195EZSQDW3E21  1384719342
# 3      A2C00NNG1ZQQG2  1384719342
# 4       A94QU4C90B1AX  1384719342
# ...               ...         ...
# 10256  A14B2YH83ZXMPP  B00JBIVXGC
# 10257   A1RPTVW5VEOSI  B00JBIVXGC
# 10258   AWCJ12KBO5VII  B00JBIVXGC
# 10259  A2Z7S8B5U4PAKJ  B00JBIVXGC
# 10260  A2WA8TDCTGUADI  B00JBIVXGC
#
#                                            reviewerName   helpful  \
# 0      cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                                  Jake  [13, 14]
# 2                         Rick Bennette "Rick Bennette"    [1, 1]
# 3                             RustyBill "Sunday Rocker"    [0, 0]
# 4                                         SEAN MASLANKA    [0, 0]
# ...                                                 ...       ...
# 10256                                   Lonnie M. Adams    [0, 0]
# 10257                                Michael J. Edelman    [0, 0]
# 10258                                  Michael L. Knapp    [0, 0]
# 10259                           Rick Langdon "Scriptor"    [0, 0]
# 10260                                   TheTerrorBeyond    [0, 0]
#
#                                               reviewText  overall  \
# 0      Not much to write about here, but it does exac...      5.0
# 1      The product does exactly as it should and is q...      5.0
# 2      The primary job of this device is to block the...      5.0
# 3      Nice windscreen protects my MXL mic and preven...      5.0
# 4      This pop filter is great. It looks and perform...      5.0
# ...                                                  ...      ...
# 10256            Great, just as expected.  Thank to all.      5.0
# 10257  I've been thinking about trying the Nanoweb st...      5.0
# 10258  I have tried coated strings in the past ( incl...      4.0
# 10259  Well, MADE by Elixir and DEVELOPED with Taylor...      4.0
# 10260  These strings are really quite good, but I wou...      4.0
#
#                                                  summary  unixReviewTime  \
# 0                                                   good      1393545600
# 1                                                   Jake      1363392000
# 2                                   It Does The Job Well      1377648000
# 3                          GOOD WINDSCREEN FOR THE MONEY      1392336000
# 4                  No more pops when I record my vocals.      1392940800
# ...                                                  ...             ...
# 10256                                         Five Stars      1405814400
# 10257  Long life, and for some players, a good econom...      1404259200
# 10258                                   Good for coated.      1405987200
# 10259                                        Taylor Made      1404172800
# 10260  These strings are really quite good, but I wou...      1405468800
#
#         reviewTime
# 0      02 28, 2014
# 1      03 16, 2013
# 2      08 28, 2013
# 3      02 14, 2014
# 4      02 21, 2014
# ...            ...
# 10256  07 20, 2014
# 10257   07 2, 2014
# 10258  07 22, 2014
# 10259   07 1, 2014
# 10260  07 16, 2014
#
# [10261 rows x 9 columns]

# %% [markdown]
# ### Extract Summary Column

# %%
sentences = df['summary']
sentences = sentences.apply(lambda str: str.lower())
sentences
# Out:
# 0                                                     good
# 1                                                     jake
# 2                                     it does the job well
# 3                            good windscreen for the money
# 4                    no more pops when i record my vocals.
#                                ...
# 10256                                           five stars
# 10257    long life, and for some players, a good econom...
# 10258                                     good for coated.
# 10259                                          taylor made
# 10260    these strings are really quite good, but i wou...
# Name: summary, Length: 10261, dtype: object

# %% [markdown]
# ### Perform text processing
#
# **Using the nltk package for Tokenization, Stemming, and Lemmatization

# %% [markdown]
# #### Tokenization

# %%
# Create tokens
tokens = sentences.apply(lambda sentence: word_tokenize(sentence))
tokens
# Out:
# 0                                                   [good]
# 1                                                   [jake]
# 2                               [it, does, the, job, well]
# 3                      [good, windscreen, for, the, money]
# 4         [no, more, pops, when, i, record, my, vocals, .]
#                                ...
# 10256                                        [five, stars]
# 10257    [long, life, ,, and, for, some, players, ,, a,...
# 10258                               [good, for, coated, .]
# 10259                                       [taylor, made]
# 10260    [these, strings, are, really, quite, good, ,, ...
# Name: summary, Length: 10261, dtype: object

# %% [markdown]
# ### Stemming

# %%
ps = PorterStemmer()

stemmed_tokens = tokens.apply(lambda x: [ps.stem(token) for token in x])
stemmed_tokens
# Out:
# 0                                                   [good]
# 1                                                   [jake]
# 2                                [it, doe, the, job, well]
# 3                      [good, windscreen, for, the, money]
# 4           [no, more, pop, when, i, record, my, vocal, .]
#                                ...
# 10256                                         [five, star]
# 10257    [long, life, ,, and, for, some, player, ,, a, ...
# 10258                                 [good, for, coat, .]
# 10259                                       [taylor, made]
# 10260    [these, string, are, realli, quit, good, ,, bu...
# Name: summary, Length: 10261, dtype: object

# %% [markdown]
# #### Lemmatization

# %%
wl = WordNetLemmatizer()

lemma_tokens = tokens.apply(lambda x: [wl.lemmatize(token) for token in x])
lemma_tokens
# Out:
# 0                                                   [good]
# 1                                                   [jake]
# 2                                [it, doe, the, job, well]
# 3                      [good, windscreen, for, the, money]
# 4           [no, more, pop, when, i, record, my, vocal, .]
#                                ...
# 10256                                         [five, star]
# 10257    [long, life, ,, and, for, some, player, ,, a, ...
# 10258                               [good, for, coated, .]
# 10259                                       [taylor, made]
# 10260    [these, string, are, really, quite, good, ,, b...
# Name: summary, Length: 10261, dtype: object

# %% [markdown]
# ### Print out results

# %%
# Find results where there is a big change in the tokens sue to stemming or lemmatization
# Assumption here that if there is a big change in the token and lemmatized token then
# there a likely chance where the stemmed token has changes in it too
test_indices = []
for i, (tokens1, tokens2) in enumerate(zip(tokens, lemma_tokens)):
    if tokens1 != tokens2:
        for t1, t2 in zip(tokens1, tokens2):
            cnt = abs(len(t1) - len(t2))
            for c1, c2 in zip(t1, t2):
                if c1 != c2:
                    cnt += 1 
            if cnt > 1:
                test_indices += [i]

# %%
random_indices = np.random.choice(test_indices, 50)
for i in random_indices:
    print(i)
    print(tokens[i])
    print(stemmed_tokens[i])
    print(lemma_tokens[i])
    print()
# Out:
# 6627
# ['your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'feet', ')', 'your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'feet', ')']
# ['your', 'cabl', 'store', 'xlr', '3', 'pin', 'microphon', 'cabl', '(', '6', 'feet', ')', 'your', 'cabl', 'store', 'xlr', '3', 'pin', 'microphon', 'cabl', '(', '6', 'feet', ')']
# ['your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'foot', ')', 'your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'foot', ')']
#
# 3139
# ['will', 'likely', 'not', 'get', 'two', 'or', 'three', 'uses', 'out', 'of', 'them']
# ['will', 'like', 'not', 'get', 'two', 'or', 'three', 'use', 'out', 'of', 'them']
# ['will', 'likely', 'not', 'get', 'two', 'or', 'three', 'us', 'out', 'of', 'them']
#
# 8404
# ['not', '20', 'feet', ';', 'about', '6.5', 'feet', 'instead', ';', 'maybe', 'that', 'matters']
# ['not', '20', 'feet', ';', 'about', '6.5', 'feet', 'instead', ';', 'mayb', 'that', 'matter']
# ['not', '20', 'foot', ';', 'about', '6.5', 'foot', 'instead', ';', 'maybe', 'that', 'matter']
#
# 8408
# ['i', 'will', 'finally', 'hear', 'a', 'great', 'hisssss', 'in', 'my', 'earphone', '!']
# ['i', 'will', 'final', 'hear', 'a', 'great', 'hisssss', 'in', 'my', 'earphon', '!']
# ['i', 'will', 'finally', 'hear', 'a', 'great', 'hiss', 'in', 'my', 'earphone', '!']
#
# 2545
# ['so', 'underrated', '-', 'a', 'must-have', 'for', 'any', 'performing/aspiring', 'vocalist', ',', 'podcaster', 'or', 'anyone', 'who', 'uses', 'microphones', 'for', 'live', 'audio', '.']
# ['so', 'underr', '-', 'a', 'must-hav', 'for', 'ani', 'performing/aspir', 'vocalist', ',', 'podcast', 'or', 'anyon', 'who', 'use', 'microphon', 'for', 'live', 'audio', '.']
# ['so', 'underrated', '-', 'a', 'must-have', 'for', 'any', 'performing/aspiring', 'vocalist', ',', 'podcaster', 'or', 'anyone', 'who', 'us', 'microphone', 'for', 'live', 'audio', '.']
#
# 485
# ['the', 'legend', 'lives', 'on', '...']
# ['the', 'legend', 'live', 'on', '...']
# ['the', 'legend', 'life', 'on', '...']
#
# 2545
# ['so', 'underrated', '-', 'a', 'must-have', 'for', 'any', 'performing/aspiring', 'vocalist', ',', 'podcaster', 'or', 'anyone', 'who', 'uses', 'microphones', 'for', 'live', 'audio', '.']
# ['so', 'underr', '-', 'a', 'must-hav', 'for', 'ani', 'performing/aspir', 'vocalist', ',', 'podcast', 'or', 'anyon', 'who', 'use', 'microphon', 'for', 'live', 'audio', '.']
# ['so', 'underrated', '-', 'a', 'must-have', 'for', 'any', 'performing/aspiring', 'vocalist', ',', 'podcaster', 'or', 'anyone', 'who', 'us', 'microphone', 'for', 'live', 'audio', '.']
#
# 3968
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'les', 'pauls', '(', 'and', 'copies', ')']
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'le', 'paul', '(', 'and', 'copi', ')']
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'le', 'paul', '(', 'and', 'copy', ')']
#
# 8404
# ['not', '20', 'feet', ';', 'about', '6.5', 'feet', 'instead', ';', 'maybe', 'that', 'matters']
# ['not', '20', 'feet', ';', 'about', '6.5', 'feet', 'instead', ';', 'mayb', 'that', 'matter']
# ['not', '20', 'foot', ';', 'about', '6.5', 'foot', 'instead', ';', 'maybe', 'that', 'matter']
#
# 5697
# ['finally', '!', '!', 'something', 'accurately', 'monitors', 'my', 'axe-fx', '2', 'for', 'less', 'than', '$', '150', '!', 'blows', 'senheiser', 'hd', '280', 'pro', 'out', 'of', 'the', 'water', '!', '!', '!']
# ['final', '!', '!', 'someth', 'accur', 'monitor', 'my', 'axe-fx', '2', 'for', 'less', 'than', '$', '150', '!', 'blow', 'senheis', 'hd', '280', 'pro', 'out', 'of', 'the', 'water', '!', '!', '!']
# ['finally', '!', '!', 'something', 'accurately', 'monitor', 'my', 'axe-fx', '2', 'for', 'le', 'than', '$', '150', '!', 'blow', 'senheiser', 'hd', '280', 'pro', 'out', 'of', 'the', 'water', '!', '!', '!']
#
# 6849
# ['just', 'perfect', 'for', 'stomp', 'boxes']
# ['just', 'perfect', 'for', 'stomp', 'box']
# ['just', 'perfect', 'for', 'stomp', 'box']
#
# 4829
# ['dead', 'after', 'less', 'than', 'a', 'year']
# ['dead', 'after', 'less', 'than', 'a', 'year']
# ['dead', 'after', 'le', 'than', 'a', 'year']
#
# 649
# ['great', 'cable', '-', 'matches', 'my', 'blues', 'jr', '.']
# ['great', 'cabl', '-', 'match', 'my', 'blue', 'jr', '.']
# ['great', 'cable', '-', 'match', 'my', 'blue', 'jr', '.']
#
# 8763
# ['great', 'guitar', 'for', 'less', 'than', '$', '100']
# ['great', 'guitar', 'for', 'less', 'than', '$', '100']
# ['great', 'guitar', 'for', 'le', 'than', '$', '100']
#
# 4604
# ['a', 'less', 'convenient', 'way', 'to', 'get', 'the', 'job', 'done', '.']
# ['a', 'less', 'conveni', 'way', 'to', 'get', 'the', 'job', 'done', '.']
# ['a', 'le', 'convenient', 'way', 'to', 'get', 'the', 'job', 'done', '.']
#
# 5417
# ['great', 'for', 'all', 'stomp', 'boxes']
# ['great', 'for', 'all', 'stomp', 'box']
# ['great', 'for', 'all', 'stomp', 'box']
#
# 9351
# ['ableton', 'crashes', 'even', 'with', 'latest', 'drivers', 'and', 'makes', 'a', 'poping', 'sound']
# ['ableton', 'crash', 'even', 'with', 'latest', 'driver', 'and', 'make', 'a', 'pope', 'sound']
# ['ableton', 'crash', 'even', 'with', 'latest', 'driver', 'and', 'make', 'a', 'poping', 'sound']
#
# 9871
# ['mooer', 'pitch', 'box', ';', 'organ', 'like', 'harmonies']
# ['mooer', 'pitch', 'box', ';', 'organ', 'like', 'harmoni']
# ['mooer', 'pitch', 'box', ';', 'organ', 'like', 'harmony']
#
# 6849
# ['just', 'perfect', 'for', 'stomp', 'boxes']
# ['just', 'perfect', 'for', 'stomp', 'box']
# ['just', 'perfect', 'for', 'stomp', 'box']
#
# 5296
# ['great', 'portable', 'acoustic', 'guitar', 'stand', 'that', "'s", 'safe', 'for', 'most', 'finishes']
# ['great', 'portabl', 'acoust', 'guitar', 'stand', 'that', "'s", 'safe', 'for', 'most', 'finish']
# ['great', 'portable', 'acoustic', 'guitar', 'stand', 'that', "'s", 'safe', 'for', 'most', 'finish']
#
# 2241
# ['functions', 'well', 'enough', '.', 'construction', 'leaves', 'some', 'to', 'be', 'desired', '.']
# ['function', 'well', 'enough', '.', 'construct', 'leav', 'some', 'to', 'be', 'desir', '.']
# ['function', 'well', 'enough', '.', 'construction', 'leaf', 'some', 'to', 'be', 'desired', '.']
#
# 4220
# ['stock', 'up', 'on', 'batteries', '!']
# ['stock', 'up', 'on', 'batteri', '!']
# ['stock', 'up', 'on', 'battery', '!']
#
# 4620
# ['very', 'good', 'cleaner/lube', 'that', 'is', 'gentle', 'on', 'delicate', 'finishes']
# ['veri', 'good', 'cleaner/lub', 'that', 'is', 'gentl', 'on', 'delic', 'finish']
# ['very', 'good', 'cleaner/lube', 'that', 'is', 'gentle', 'on', 'delicate', 'finish']
#
# 4929
# ['ok', 'for', 'experimentation', ',', 'but', 'for', 'less', 'noise', ',', 'go', 'elsewhere']
# ['ok', 'for', 'experiment', ',', 'but', 'for', 'less', 'nois', ',', 'go', 'elsewher']
# ['ok', 'for', 'experimentation', ',', 'but', 'for', 'le', 'noise', ',', 'go', 'elsewhere']
#
# 6437
# ['it', "'s", 'a', 'diabolical', 'reference', 'thingie-ma-doodle', 'for', 'the', 'geniuses', 'among', 'us', '.']
# ['it', "'s", 'a', 'diabol', 'refer', 'thingie-ma-doodl', 'for', 'the', 'genius', 'among', 'us', '.']
# ['it', "'s", 'a', 'diabolical', 'reference', 'thingie-ma-doodle', 'for', 'the', 'genius', 'among', 'u', '.']
#
# 5444
# ['do', "n't", 'pay', '$', '200', 'for', 'other', 'power', 'supplies']
# ['do', "n't", 'pay', '$', '200', 'for', 'other', 'power', 'suppli']
# ['do', "n't", 'pay', '$', '200', 'for', 'other', 'power', 'supply']
#
# 236
# ['xlr', 'male', 'to', 'xlr', 'female', 'microphone', 'cable', '-', '15', 'feet']
# ['xlr', 'male', 'to', 'xlr', 'femal', 'microphon', 'cabl', '-', '15', 'feet']
# ['xlr', 'male', 'to', 'xlr', 'female', 'microphone', 'cable', '-', '15', 'foot']
#
# 2156
# ['the', 'strings', 'frusciante', 'uses']
# ['the', 'string', 'frusciant', 'use']
# ['the', 'string', 'frusciante', 'us']
#
# 9776
# ['got', 'two', 'of', 'them', 'for', 'less', 'than', 'the', 'price', 'of', 'one', 'locally']
# ['got', 'two', 'of', 'them', 'for', 'less', 'than', 'the', 'price', 'of', 'one', 'local']
# ['got', 'two', 'of', 'them', 'for', 'le', 'than', 'the', 'price', 'of', 'one', 'locally']
#
# 478
# ['i', 'love', 'it', '.', 'works', 'great', '.', 'so', 'many', 'possibilities']
# ['i', 'love', 'it', '.', 'work', 'great', '.', 'so', 'mani', 'possibl']
# ['i', 'love', 'it', '.', 'work', 'great', '.', 'so', 'many', 'possibility']
#
# 6627
# ['your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'feet', ')', 'your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'feet', ')']
# ['your', 'cabl', 'store', 'xlr', '3', 'pin', 'microphon', 'cabl', '(', '6', 'feet', ')', 'your', 'cabl', 'store', 'xlr', '3', 'pin', 'microphon', 'cabl', '(', '6', 'feet', ')']
# ['your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'foot', ')', 'your', 'cable', 'store', 'xlr', '3', 'pin', 'microphone', 'cable', '(', '6', 'foot', ')']
#
# 478
# ['i', 'love', 'it', '.', 'works', 'great', '.', 'so', 'many', 'possibilities']
# ['i', 'love', 'it', '.', 'work', 'great', '.', 'so', 'mani', 'possibl']
# ['i', 'love', 'it', '.', 'work', 'great', '.', 'so', 'many', 'possibility']
#
# 3968
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'les', 'pauls', '(', 'and', 'copies', ')']
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'le', 'paul', '(', 'and', 'copi', ')']
# ['perfect', '+1', 'for', 'more', 'tone', 'from', 'le', 'paul', '(', 'and', 'copy', ')']
#
# 2644
# ['terrible', '!', 'leaves', 'little', 'fibers', 'everywhere', '.']
# ['terribl', '!', 'leav', 'littl', 'fiber', 'everywher', '.']
# ['terrible', '!', 'leaf', 'little', 'fiber', 'everywhere', '.']
#
# 561
# ['ok', 'if', 'you', 'got', 'alot', 'of', 'axes', 'and', 'a', 'fav', 'strap']
# ['ok', 'if', 'you', 'got', 'alot', 'of', 'axe', 'and', 'a', 'fav', 'strap']
# ['ok', 'if', 'you', 'got', 'alot', 'of', 'ax', 'and', 'a', 'fav', 'strap']
#
# 2141
# ['lives', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorite', 'strings', '.']
# ['live', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorit', 'string', '.']
# ['life', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorite', 'string', '.']
#
# 5740
# ['get', 'your', 'reading', 'glasses', 'on', '!']
# ['get', 'your', 'read', 'glass', 'on', '!']
# ['get', 'your', 'reading', 'glass', 'on', '!']
#
# 5416
# ['yay', '!', '!', 'no', 'more', 'batteries', '!', '!']
# ['yay', '!', '!', 'no', 'more', 'batteri', '!', '!']
# ['yay', '!', '!', 'no', 'more', 'battery', '!', '!']
#
# 5417
# ['great', 'for', 'all', 'stomp', 'boxes']
# ['great', 'for', 'all', 'stomp', 'box']
# ['great', 'for', 'all', 'stomp', 'box']
#
# 7483
# ['the', 'yeti', 'lives', 'on', 'top', 'of', 'the', 'mountain']
# ['the', 'yeti', 'live', 'on', 'top', 'of', 'the', 'mountain']
# ['the', 'yeti', 'life', 'on', 'top', 'of', 'the', 'mountain']
#
# 4902
# ['think', '``', 'lightning', 'crashes', "''"]
# ['think', '``', 'lightn', 'crash', "''"]
# ['think', '``', 'lightning', 'crash', "''"]
#
# 8191
# ['sharks', 'are', 'in', 'the', 'ocean', 'and', 'are', 'dangerous', '..', 'a', 'snark', 'will', 'tune', 'sweet', 'pitches']
# ['shark', 'are', 'in', 'the', 'ocean', 'and', 'are', 'danger', '..', 'a', 'snark', 'will', 'tune', 'sweet', 'pitch']
# ['shark', 'are', 'in', 'the', 'ocean', 'and', 'are', 'dangerous', '..', 'a', 'snark', 'will', 'tune', 'sweet', 'pitch']
#
# 2141
# ['lives', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorite', 'strings', '.']
# ['live', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorit', 'string', '.']
# ['life', 'up', 'to', 'the', 'hype', ',', 'my', 'new', 'favorite', 'string', '.']
#
# 9284
# ['lives', 'up', 'to', 'the', 'hype']
# ['live', 'up', 'to', 'the', 'hype']
# ['life', 'up', 'to', 'the', 'hype']
#
# 6835
# ['fabulous', 'for', 'all', 'uses']
# ['fabul', 'for', 'all', 'use']
# ['fabulous', 'for', 'all', 'us']
#
# 5740
# ['get', 'your', 'reading', 'glasses', 'on', '!']
# ['get', 'your', 'read', 'glass', 'on', '!']
# ['get', 'your', 'reading', 'glass', 'on', '!']
#
# 2418
# ['planet', 'waves', 'classic', 'series', 'instrument', 'cable', ',', '5', 'feet']
# ['planet', 'wave', 'classic', 'seri', 'instrument', 'cabl', ',', '5', 'feet']
# ['planet', 'wave', 'classic', 'series', 'instrument', 'cable', ',', '5', 'foot']
#
# 4538
# ['made', 'my', 'cheap', 'mandolin', 'sound', 'less', 'cheap']
# ['made', 'my', 'cheap', 'mandolin', 'sound', 'less', 'cheap']
# ['made', 'my', 'cheap', 'mandolin', 'sound', 'le', 'cheap']
#
# 5740
# ['get', 'your', 'reading', 'glasses', 'on', '!']
# ['get', 'your', 'read', 'glass', 'on', '!']
# ['get', 'your', 'reading', 'glass', 'on', '!']
#
# 5856
# ['saves', 'you', 'a', 'ton', 'of', 'batteries', '.']
# ['save', 'you', 'a', 'ton', 'of', 'batteri', '.']
# ['save', 'you', 'a', 'ton', 'of', 'battery', '.']
